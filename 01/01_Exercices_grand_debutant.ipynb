# %% [markdown]
# # Exercice 1

# %%
name=input("Entrez votre nom : ")

print(f"Bienvenue {name} !")

# %% [markdown]
# # Exercice 2

# %%
x= int(input("Entrez un nombre entier: "))
y= int(input("Entrez un autre nombre entier: "))
z=x+y
print(f"La somme de {x} et {y} est {z}")

# %% [markdown]
# # Exercice 3

# %%
x= int(input("Entrez un nombre entier: "))
y= int(input("Entrez un autre nombre entier: "))
if x>y :
    print(f"{x} est plus grand que {y}")
else :
    print(f"{y} est plus grand que {x}")

# %% [markdown]
# # Exercice 4

# %%
for i in range(0, 100):
    print(i)

# %% [markdown]
# # Exercice 5

# %%
n= int(input("Entrez un nombre entier: "))
if n & 1:
    print(f"{n} est impair")
else:
    print(f"{n} est pair")

# %% [markdown]
# # Exercice 6

# %%
age= int(input("Entrez votre âge: "))
if age >= 18:
    print("Vous êtes Majeur !")      
else:
    print("Vous êtes mineur !")

# %% [markdown]
# # Exercice 7

# %%
x= int(input("Entrez un nombre entier: "))
y= int(input("Entrez un autre nombre entier: "))
z= int(input("Entrez un troisième nombre entier: "))

nombres = [x, y, z]
if x == y == z:
    print("Les trois nombres entrés sont égaux")
else:
    print(f"Parmi {x},{y} et {z}, le plus grand nombre est {max(nombres)}")

# %% [markdown]
# # Exercice 8

# %%
x= int(input("Entrez un nombre entier: "))
Somme=0
for i in range(1, x+1):
   Somme +=i
    
print(f"La somme des entiers de 0 à {x} est {Somme}")

# %% [markdown]
# # Exercice 9

# %%
x= int(input("Entrez un nombre entier: "))
factorielle = 1
for i in range(1, x+1):
    factorielle = factorielle * i

print(f"La factorielle de {x} est {factorielle}")

# %% [markdown]
# # Exercice 10

# %%
rayon = float(input("Entrez le rayon du cercle: "))
aire =  3.14 * rayon * rayon
périmètre = 2 * 3.14 * rayon
print(f"L'aire du cercle est {aire} et son périmètre est {périmètre}")

# %% [markdown]
# # Exercice 11

# %%
n= int(input("Entrez un nombre entier: "))
print(f"Les diviseurs de {n} sont :")
for i in range(1, n+1):
    if n % i == 0:
        print(i)

# %% [markdown]
# # Exercice 12

# %%
n= int(input("Entrez un nombre entier: "))
for i in range(1, 11):
    produit = n * i
    print(f"{n} x {i} = {produit}")

# %%
for i in range(1, 10):
    for j in range(1, 11):
        produit = i * j
        print(f"{i} x {j} = {produit}")

# %% [markdown]
# # Exercice 13

# %%
a= int(input("Entrez le premier nombre entier: "))
b= int(input("Entrez le deuxième nombre entier: "))
while b == 0:
    print("Erreur : division par zéro impossible.")
    b= int(input("Entrez un autre nombre entier différent de zéro: "))

quotient = a // b
print(f"Le quotient de {a} divisé par {b} est {quotient}")
reste = a % b
print(f"Le reste de la division de {a} par {b} est {reste}")

# %% [markdown]
# # Exercice 14

# %%
n= int(input("Entrez un nombre entier: "))
import math
if math.sqrt(n).is_integer():
    print(f"{n} est un carré parfait") 

else:
    print(f"{n} n'est pas un carré parfait")

# %% [markdown]
# # Exercice 15

# %%
n= int(input("Entrez un nombre entier: "))
for i in range(2, n):
    if n % i == 0:
        print(f"{n} n'est pas un nombre premier")
        break   

else:
    print(f"{n} est un nombre premier")

# %% [markdown]
# # Exercice 16

# %%
chaîne = str(input("Entrez un mot ou une phrase"))
print("Les caractères du texte entrés sont :")
for char in chaîne:
    print(char)

# %% [markdown]
# # Exercice 17

# %%
s = str(input("Entrez un mot: "))
s_lower = s.lower()
already_counted = ""
for char in s_lower:
    count = s_lower.count(char)
    if char in already_counted:
        continue   
    else :
        print(f"Le caractère : '{char}' apparaît {count} fois dans la chaîne ")
    
    already_counted = already_counted + char

# %% [markdown]
# # Exercice 18

# %%
s= str(input("Entrez une chaîne de caractère: "))
liste = []
for char in s:
    liste.append(char)

for i in liste:
    if i in 'aA':
        position = liste.index(i)
        print("Lettre 'a' trouvée à la position", position)
        for j in range(position + 1, len(liste)):
            if liste[j] in 'aA':
                position = j
                print("Lettre 'a' trouvée à la position", position)
        break
        
                   
else :
    print("Lettre 'a' non trouvée")

# %% [markdown]
# # Exercice 19

# %%
liste = ["laptop","iphone","tablet"]
for item in liste:
    longueur = len(item)
    print(f"Le mot {item} contient {longueur} caractères")

# %% [markdown]
# # Exercice 20

# %%
s= str(input("Entrez une chaîne de caractères: "))
premier_caractère = s[0].lower()
dernier_caractère = s[-1].upper()
nouveau_texte = dernier_caractère + s[1:-1] + premier_caractère 
print(f"Le nouveau texte est : {nouveau_texte}")

# %% [markdown]
# # Exercice 21

# %%
s= str(input("Entrez une chaîne de caractères: "))
nbr_voyelles = 0
lowercase_text = s.lower()

for char in lowercase_text:
    if char in 'aeiouy':
        nbr_voyelles +=1

print(f"La chaîne {s} contient {nbr_voyelles} voyelles")

# %% [markdown]
# # Exercice 22

# %%
s= str(input("Entrez une châine de caractères: "))
premier_mot = ""

for char in s:
    premier_mot += char
    if char == ' ':
        break


print (premier_mot)

# %% [markdown]
# # Exercice 23

# %%
s= str(input("Entrez un nom de fichier: "))
extension = ""
for i in s:
    if i == '.':
        for j in range(s.index(i)+1, len(s)):
            extension += s[j]   

print(f"L'extension du fichier est: {extension}")

# %% [markdown]
# # Exercice 24

# %%
s= str(input("Entrez un mot: "))

if s == s[::-1]:
    print(f"Le mot {s} est un palindrome")
else:
    print(f"Le mot {s} n'est pas un palindrome")

# %% [markdown]
# # Exercice 25

# %%
s= str(input("Entrez un mot: "))
chaîne_inversée = s[::-1]
print(f"Le mot inversé est: {chaîne_inversée}")

# %% [markdown]
# # Exercice 26

# %%
s= str(input("Entrez une chaîne de caractères: "))
liste_mots = s.split()

for mot in liste_mots:
    if mot.lower()[0] == 'a':
        print(mot)
    
else:
    print("Fin de la recherche")
