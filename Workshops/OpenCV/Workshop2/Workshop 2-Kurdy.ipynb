# %% [markdown]
# # Chat ou Chien !! une méthode d'apprentissage automatique.
#
# Dans une entreprise de marketing, on veut faire une étude sur les clients qui fréquentent un grand magasin. L'idée est d'estimer le pourcentage de clients qui ont des chats et ceux qui ont des chiens, afin de prendre des décisions marketing ciblées. Vous proposez d'utiliser une caméra pour détecter et compter les deux animaux dans le magasin. La première étape du projet est de développer un modèle qui peut détecter le chat ou le chien. Ainsi, dans ce brief, en utilisant une base de données, vous allez entrainer un modèle d'apprentissage automatique avec un apprentissage supervisé.

# %% [markdown]
# # Veille technologique: Opencv python
#
# - Préparation données imagerie pour méthode classique d'apprentissage automatique
# - Entrainement et évaluation (similaire aux briefs précédents)

# %% [markdown]
# ## Operations Simples

# %%
# use opencv to load and display the image
import os
import cv2
import numpy as np

# %%
# Préparer data 
size = 150
# repertoir d'images avec deux sous dossiers "Cat" et "Dog"
image_directory = 'PetImages/'
images = []  # liste pour images  
labels = []  # liste pour Label (0 ou 1) pour deux classes.

# utiliser "os" pour avoir les noms des images dans chaque sous dossier
cat_images = os.listdir(os.path.join(image_directory, "Cat"))
dog_images = os.listdir(os.path.join(image_directory, "Dog"))
print(f"Nombre d'images de chats : {len(cat_images)}")
print(f"Nombre d'images de chiens : {len(dog_images)}")
print(f"Exemples chats : {cat_images[:5]}")
print(f"Exemples chiens : {dog_images[:5]}")

# utiliser une boucle pour lire chaque image, redimensionner en (150,150,3),
# et la mettre dans images, et mettre le label(0 ou 1) selon le type dans "label"

# il y a des images corrumpues, utiliser try ... catch except pour les ignorer


# boucle pour les images Cat

for file in cat_images :
    try:
        img = cv2.imread(os.path.join(image_directory, "Cat", file))
        img = cv2.resize(img, (150,150))
        images.append(img)
        labels.append(0)
    except:
        print(f"Image corrompue ignorée : {file}")


# boucle pour les images Dog   

for file in dog_images :
    try:
        img = cv2.imread(os.path.join(image_directory, "Dog", file))
        img = cv2.resize(img, (150,150))
        images.append(img)
        labels.append(1)
    except:
        print(f"Image corrompue ignorée : {file}")

# transformer les listes en numpy 
images = np.array(images)
labels = np.array(labels)

# save data as ".npy" file

saved_images = np.save("ImagesCatDog", images)
saved_labels = np.save("LabelsCatDog", labels)

# show shape

print(f"Shape de l'array des images : {images.shape}")
print(f"Shape de l'array des labels : {labels.shape}")
print(f"Chats : {np.sum(labels == 0)}, Chiens : {np.sum(labels == 1)}")
# Out:
# Nombre d'images de chats : 12501
# Nombre d'images de chiens : 12500
# Exemples chats : ['0.jpg', '1.jpg', '10.jpg', '100.jpg', '1000.jpg']
# Exemples chiens : ['0.jpg', '1.jpg', '10.jpg', '100.jpg', '1000.jpg']
# Image corrompue ignorée : 10404.jpg
# Image corrompue ignorée : 666.jpg
# Image corrompue ignorée : Thumbs.db
# Image corrompue ignorée : 11702.jpg
# Image corrompue ignorée : Thumbs.db
# Shape de l'array des images : (24996, 150, 150, 3)
# Shape de l'array des labels : (24996,)
# Chats : 12498, Chiens : 12498

# %%
# prepare data for classical machine learning model

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# utiliser reshape pour redimensionner les données images (exemple: (120,150,150,3) ---> (120,150*150*3). Le reshape est seulement nécessaire pour utiliser un MLP
# pas nécessaire avec keras/TF CNN
images_flat = images.reshape(24996, 150 * 150 * 3) 

# split les données en train et test avec "stratification"
X_train, X_test, y_train, y_test = train_test_split(
    images_flat, labels, test_size=0.2, random_state=42, stratify=labels
)
# on stratify selon les labels pour garder le même ratio chat/chien

print(f"Train : {X_train.shape}, Test : {X_test.shape}")
# Out:
# Train : (19996, 67500), Test : (5000, 67500)

# %%
images_flat.shape
# Out:
# (24996, 67500)

# %%
# initialiser le classifier
rf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)

# entrainer le classifier
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
# evaluate classifier
from sklearn.metrics import classification_report

# predire
y_pred = rf.predict(X_test)

# evaluer avec classification_report
print (f"Score : {rf.score(X_test, y_test)}")
print(classification_report(y_test, y_pred))
# Out:
# Score : 0.6558
#               precision    recall  f1-score   support
#
#            0       0.64      0.71      0.67      2500
#            1       0.68      0.60      0.64      2500
#
#     accuracy                           0.66      5000
#    macro avg       0.66      0.66      0.65      5000
# weighted avg       0.66      0.66      0.65      5000

# %% [markdown]
# ### Essayer de normaliser chaque image entre 0 et 255 et rentrainer le modèle. Y a-t-il une amélioration ?

# %%
images_normalized = images / 255.0

# %%
images_normalized.shape
# Out:
# (24996, 150, 150, 3)

# %%
images_flat_normalized = images_normalized.reshape(24996, 150 * 150 * 3)

# %%
X_train_norm, X_test_norm, y_train, y_test = train_test_split(
    images_flat_normalized, labels, test_size=0.2, random_state=42, stratify=labels
)
print(f"Train : {X_train_norm.shape}, Test : {X_test_norm.shape}")
# Out:
# Train : (19996, 67500), Test : (5000, 67500)

# %%
# initialiser le classifier
rf = RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1)

# entrainer le classifier
rf.fit(X_train_norm, y_train)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
# predire
y_pred_norm = rf.predict(X_test_norm)

# evaluer avec classification_report
print (f"Score : {rf.score(X_test_norm, y_test)}")
print(classification_report(y_test, y_pred_norm))
# Out:
# Score : 0.6552
#               precision    recall  f1-score   support
#
#            0       0.64      0.71      0.67      2500
#            1       0.67      0.60      0.63      2500
#
#     accuracy                           0.66      5000
#    macro avg       0.66      0.66      0.65      5000
# weighted avg       0.66      0.66      0.65      5000

# %% [markdown]
# pas d'amélioration
# normal pour un RF

# %% [markdown]
# # Neural networ MLP
#
# Entrainer un modèle MLP pour detecter la class Dog ou Cat.

# %%
# use PCA to reduce dimensions
# check this tuto: https://www.askpython.com/python/examples/principal-component-analysis-for-image-data

from tensorflow.keras.layers import Input, Dense, Dropout, Flatten
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# creer un reseau de neurone avec une couche d'entrée de taille (150*150*3), deux couches caché de taille 128 et une activation "relu". 
# Dernière couche de taille 1 avec une activation sigmoid. Choisir la bonne "loss function" et "optimizer"

model = Sequential([
    Dense(128, activation='relu', input_shape=(150 * 150 * 3,)),
    Dense(128, activation='relu'),
    Dense(1, activation='sigmoid')
])



model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
) 

early_stopping = EarlyStopping(monitor='val_loss', patience=4)
model.summary()
# Out:
# c:\Users\alexandre.karneff\Documents\GitHub\alexandre.karneff\envWorkshop\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │     8,640,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,656,769 (33.02 MB)
#  Trainable params: 8,656,769 (33.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# entrainer le modèle avec validation_split = .2, epochs = 20, et un batch_size = 128
history = model.fit(
    X_train_norm, y_train,
    epochs=20,
    batch_size=128,
    validation_split=0.2,
    callbacks = [early_stopping]
)
# Out:
# Epoch 1/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - accuracy: 0.5254 - loss: 1.5004 - val_accuracy: 0.5332 - val_loss: 0.7522
# Epoch 2/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - accuracy: 0.5588 - loss: 0.7100 - val_accuracy: 0.5250 - val_loss: 0.7778
# Epoch 3/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.5684 - loss: 0.7195 - val_accuracy: 0.5020 - val_loss: 0.9308
# Epoch 4/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.5940 - loss: 0.6832 - val_accuracy: 0.6292 - val_loss: 0.6502
# Epoch 5/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.6130 - loss: 0.6601 - val_accuracy: 0.6097 - val_loss: 0.6609
# Epoch 6/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.5786 - loss: 0.7259 - val_accuracy: 0.5510 - val_loss: 0.7234
# Epoch 7/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.6061 - loss: 0.6650 - val_accuracy: 0.6305 - val_loss: 0.6467
# Epoch 8/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.6148 - loss: 0.6555 - val_accuracy: 0.5882 - val_loss: 0.6675
# Epoch 9/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.6294 - loss: 0.6370 - val_accuracy: 0.6177 - val_loss: 0.6528
# Epoch 10/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.6362 - loss: 0.6353 - val_accuracy: 0.6265 - val_loss: 0.6622
# Epoch 11/20
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.6396 - loss: 0.6339 - val_accuracy: 0.6245 - val_loss: 0.6469

# %%
# evaluate MLP
# evaluate classifier
from sklearn.metrics import classification_report
# predire

# evaluer avec classification_report

# Prédire
y_pred_proba = model.predict(X_test_norm)
y_pred = (y_pred_proba > 0.5).astype(int).flatten()

# Évaluer
print(classification_report(y_test, y_pred, target_names=['Chat', 'Chien']))
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#               precision    recall  f1-score   support
#
#         Chat       0.64      0.63      0.63      2500
#        Chien       0.63      0.64      0.64      2500
#
#     accuracy                           0.63      5000
#    macro avg       0.63      0.63      0.63      5000
# weighted avg       0.63      0.63      0.63      5000

# %% [markdown]
# # CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
# Re-split depuis les images originales (4D, pas flat)
X_train_cnn, X_test_cnn, y_train, y_test = train_test_split(
    images, labels, test_size=0.2, random_state=42, stratify=labels
)

# %%
# Normaliser
X_train_cnn = X_train_cnn / 255.0
X_test_cnn = X_test_cnn / 255.0

# %%
print(X_train_cnn.shape)
# Out:
# (19996, 150, 150, 3)

# %%
# Modèle CNN
model_cnn = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model_cnn.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)
# Out:
# c:\Users\alexandre.karneff\Documents\GitHub\alexandre.karneff\envWorkshop\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model_cnn.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 36992)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │     4,735,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,828,481 (18.42 MB)
#  Trainable params: 4,828,481 (18.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Prendre seulement 5000 images
# X_train_small = X_train_cnn[:5000]
# y_train_small = y_train[:5000]

# %%
history = model_cnn.fit(X_train_cnn, y_train, epochs=10, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 61s 244ms/step - accuracy: 0.7025 - loss: 0.5781 - val_accuracy: 0.7607 - val_loss: 0.5086
# Epoch 2/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 61s 242ms/step - accuracy: 0.7713 - loss: 0.4805 - val_accuracy: 0.7818 - val_loss: 0.4631
# Epoch 3/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 60s 238ms/step - accuracy: 0.8099 - loss: 0.4174 - val_accuracy: 0.8175 - val_loss: 0.4038
# Epoch 4/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 60s 240ms/step - accuracy: 0.8418 - loss: 0.3594 - val_accuracy: 0.8090 - val_loss: 0.4226
# Epoch 5/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 60s 240ms/step - accuracy: 0.8702 - loss: 0.3028 - val_accuracy: 0.8347 - val_loss: 0.3760
# Epoch 6/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 61s 243ms/step - accuracy: 0.8969 - loss: 0.2479 - val_accuracy: 0.8382 - val_loss: 0.4053
# Epoch 7/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 62s 249ms/step - accuracy: 0.9230 - loss: 0.1878 - val_accuracy: 0.8360 - val_loss: 0.4470
# Epoch 8/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 61s 242ms/step - accuracy: 0.9445 - loss: 0.1439 - val_accuracy: 0.8290 - val_loss: 0.4806
# Epoch 9/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 60s 242ms/step - accuracy: 0.9602 - loss: 0.1084 - val_accuracy: 0.8350 - val_loss: 0.5744
# Epoch 10/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 60s 240ms/step - accuracy: 0.9655 - loss: 0.0896 - val_accuracy: 0.8382 - val_loss: 0.5981

# %%
y_pred_cnn = (model_cnn.predict(X_test_cnn) > 0.5).astype(int).flatten()
print(classification_report(y_test, y_pred_cnn, target_names=['Chat', 'Chien']))
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step
#               precision    recall  f1-score   support
#
#         Chat       0.81      0.88      0.85      2500
#        Chien       0.87      0.80      0.83      2500
#
#     accuracy                           0.84      5000
#    macro avg       0.84      0.84      0.84      5000
# weighted avg       0.84      0.84      0.84      5000
